# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (0.1.12)
# Requirement already satisfied: PyYAML>=5.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.28 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (0.0.28)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.31 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (0.1.32)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (0.1.29)
# Requirement already satisfied: numpy<2,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain) (4.3.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain) (1.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (0.0.28)
# Requirement already satisfied: PyYAML>=5.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (0.6.4)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.31 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (0.1.32)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (0.1.29)
# Requirement already satisfied: numpy<2,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: anyio<5,>=3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain-community) (4.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain-community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain-community) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.31->langchain-community) (2.6.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.9.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain-community) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.31->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.31->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.31->langchain-community) (2.16.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (0.1.32)
# Requirement already satisfied: PyYAML>=5.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (4.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (0.1.29)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: idna>=2.8 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain-core) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-experimental
# Out:
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.0.55-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain<0.2.0,>=0.1.13 (from langchain-experimental)
#   Downloading langchain-0.1.13-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-core<0.2.0,>=0.1.33 (from langchain-experimental)
#   Downloading langchain_core-0.1.33-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (1.33)
# Collecting langchain-community<0.1,>=0.0.29 (from langchain<0.2.0,>=0.1.13->langchain-experimental)
#   Downloading langchain_community-0.0.29-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (0.1.29)
# Requirement already satisfied: numpy<2,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.13->langchain-experimental) (8.2.3)
# Requirement already satisfied: anyio<5,>=3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-experimental) (4.3.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain-experimental) (23.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.13->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.13->langchain-experimental) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.13->langchain-experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.13->langchain-experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.13->langchain-experimental) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain-experimental) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain-experimental) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.13->langchain-experimental) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.13->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.13->langchain-experimental) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.13->langchain-experimental) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.13->langchain-experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.13->langchain-experimental) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.13->langchain-experimental) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.13->langchain-experimental) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.13->langchain-experimental) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.13->langchain-experimental) (2024.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.13->langchain-experimental) (1.0.0)
# Downloading langchain_experimental-0.0.55-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 5.1 MB/s eta 0:00:00
# Downloading langchain-0.1.13-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 25.7 MB/s eta 0:00:00
# Downloading langchain_core-0.1.33-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 18.2 MB/s eta 0:00:00
# Downloading langchain_community-0.0.29-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 53.2 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain-community, langchain, langchain-experimental
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.32
#     Uninstalling langchain-core-0.1.32:
#       Successfully uninstalled langchain-core-0.1.32
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.28
#     Uninstalling langchain-community-0.0.28:
#       Successfully uninstalled langchain-community-0.0.28
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.12
#     Uninstalling langchain-0.1.12:
#       Successfully uninstalled langchain-0.1.12
# Successfully installed langchain-0.1.13 langchain-community-0.0.29 langchain-core-0.1.33 langchain-experimental-0.0.55
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-cli
# Out:
# Collecting langchain-cli
#   Downloading langchain_cli-0.0.21-py3-none-any.whl.metadata (1.3 kB)
# Collecting gitpython<4.0.0,>=3.1.40 (from langchain-cli)
#   Using cached GitPython-3.1.42-py3-none-any.whl.metadata (12 kB)
# Collecting langserve>=0.0.16 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading langserve-0.0.51-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 1.7 MB/s eta 0:00:00
# Collecting tomlkit<0.13.0,>=0.12.2 (from langchain-cli)
#   Downloading tomlkit-0.12.4-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typer[all]<0.10.0,>=0.9.0->langchain-cli) (0.9.0)
# Collecting uvicorn<0.24.0,>=0.23.2 (from langchain-cli)
#   Downloading uvicorn-0.23.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4.0.0,>=3.1.40->langchain-cli)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.23.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.27.0)
# Requirement already satisfied: langchain>=0.0.333 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.1.13)
# Requirement already satisfied: orjson>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.9.15)
# Requirement already satisfied: pydantic>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.6.4)
# Requirement already satisfied: fastapi<1,>=0.90.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langserve[all]>=0.0.16->langchain-cli) (0.110.0)
# Collecting httpx-sse>=0.3.1 (from langserve[all]>=0.0.16->langchain-cli)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting sse-starlette<2.0.0,>=1.3.0 (from langserve[all]>=0.0.16->langchain-cli)
#   Using cached sse_starlette-1.8.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typer<0.10.0,>=0.9.0->typer[all]<0.10.0,>=0.9.0->langchain-cli) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typer<0.10.0,>=0.9.0->typer[all]<0.10.0,>=0.9.0->langchain-cli) (4.10.0)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich<14.0.0,>=10.11.0 (from typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: h11>=0.8 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from uvicorn<0.24.0,>=0.23.2->langchain-cli) (0.14.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from fastapi<1,>=0.90.1->langserve[all]>=0.0.16->langchain-cli) (0.36.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.40->langchain-cli)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: anyio in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (4.3.0)
# Requirement already satisfied: certifi in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.0.4)
# Requirement already satisfied: idna in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.6)
# Requirement already satisfied: sniffio in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.1.29)
# Requirement already satisfied: numpy<2,>=1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic>=1->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from pydantic>=1->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.16.3)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli) (2.17.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.33->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (23.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<0.10.0,>=0.9.0->langchain-cli)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (2.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/colinmcnamara/Code/austin_langchain/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.0.333->langserve>=0.0.16->langserve[all]>=0.0.16->langchain-cli) (1.0.0)
# Downloading langchain_cli-0.0.21-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 4.5 MB/s eta 0:00:00
# Using cached GitPython-3.1.42-py3-none-any.whl (195 kB)
# Downloading langserve-0.0.51-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.3 MB/s eta 0:00:00a 0:00:01
# Downloading tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.6 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 22.8 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sse_starlette-1.8.2-py3-none-any.whl (8.9 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.2 MB/s eta 0:00:00
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: uvicorn, tomlkit, smmap, shellingham, mdurl, httpx-sse, colorama, markdown-it-py, gitdb, rich, gitpython, sse-starlette, langserve, langchain-cli
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.28.1
#     Uninstalling uvicorn-0.28.1:
#       Successfully uninstalled uvicorn-0.28.1
# Successfully installed colorama-0.4.6 gitdb-4.0.11 gitpython-3.1.42 httpx-sse-0.4.0 langchain-cli-0.0.21 langserve-0.0.51 markdown-it-py-3.0.0 mdurl-0.1.2 rich-13.7.1 shellingham-1.5.4 smmap-5.0.1 sse-starlette-1.8.2 tomlkit-0.12.4 uvicorn-0.23.2
# Note: you may need to restart the kernel to use updated packages.
